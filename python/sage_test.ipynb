# %%
f(x)=x*cos(1/x)

# %%
p=plot(f,(x,-0.1,0.1),color='green',thickness=0.5,linestyle="--",legend_label=r"$\sin(x) \sum_{i=1}^{n}$")
p1=plot(x,-0.1,0.1,color='red')
show(p+p1,figsize=8)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f=piecewise([((0,1),1+x^3),([-1,0],1+x)])
f.plot(-1,2)
# Out:
# verbose 0 (3838: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 67 points.
# verbose 0 (3838: plot.py, generate_plot_points) Last error message: 'point 2.0 is not in the domain'
# Graphics object consisting of 1 graphics primitive

# %%
var('x,y')
n=4
f(x,y)=x^n+y^n-1
implicit_plot(f,(x,-2,2),(y,-2,2),color='rosybrown')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
v1=vector(QQ,[1,2,3])
v2=vector(QQ,[4,5,6])
v3=vector(QQ,[7,8,9])
A=matrix([v1,v2,v3])
show(A)
# Out:
# [1 2 3]
# [4 5 6]
# [7 8 9]

# %%
m,n=A.dimensions()
V=QQ^n
W=QQ^m
A.columns()
V.span(A.rows())
A.row_space()
A.nullity()
W.span(A.column_space())
# Out:
# Vector space of degree 3 and dimension 2 over Rational Field
# Basis matrix:
# [ 1  0 -1]
# [ 0  1  2]

# %%
A.rref()
# Out:
# [ 1  0 -1]
# [ 0  1  2]
# [ 0  0  0]

# %%
(A.T).rref()
# Out:
# [ 1  0 -1]
# [ 0  1  2]
# [ 0  0  0]

# %%
A.left_kernel()
# Out:
# Vector space of degree 3 and dimension 1 over Rational Field
# Basis matrix:
# [ 1 -2  1]

# %%
x=list(var('x_%d' %i) for i in range(1,4))
vector(x)
eqn=list(A*vector(x))
solve([eqn[i]==0 for i in range(3)],x,solution_dict=True)
# Out:
# [{x_1: r1, x_2: -2*r1, x_3: r1}]

# %%
uz = vector(ZZ,[1,-2,3])
uQ = vector(QQ,[1,0,3])
uR = vector(RR,[1,3,-1])
uC = vector(CC,[1,-2,2]) # complex numbers
uF = vector(GF(5),[1,-2,2]) # vector over finite fields
u = vector([1,2,3])
v = vector([2,-1,2])
w = vector([1,1,-2])
p = u.plot(color='red') + v.plot(color='green') + w.plot(color='blue')
show(vplot)
# Out:
# Graphics3d Object

# %%
u.norm()
# Out:
# sqrt(14)

# %%
u.dot_product(u)
u.cross_product(v)
# Out:
# (7, 4, -5)

# %%
plot(u.dot_product(v)/v.dot_product(v)*v)
# Out:
# Graphics3d Object

# %%
A = matrix(RR,[[1,1,3,1],[2,3,2,1],[6,3,2,2],[1,1,2,2]])

A.T
A.determinant()
A.inverse()
A.adjugate()
# Out:
# [1.00000000000000 2.00000000000000 6.00000000000000 1.00000000000000]
# [1.00000000000000 3.00000000000000 3.00000000000000 1.00000000000000]
# [3.00000000000000 2.00000000000000 2.00000000000000 2.00000000000000]
# [1.00000000000000 1.00000000000000 2.00000000000000 2.00000000000000]
